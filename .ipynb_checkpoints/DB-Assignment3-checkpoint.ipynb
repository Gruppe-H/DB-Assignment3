# %%
#!pip install -U neo4j 
# !pip install neo4j
# Out:
# Requirement already satisfied: neo4j in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (5.20.0)
# Requirement already satisfied: pytz in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from neo4j) (2023.4)

# %%
# !pip install "/Users/mariamcnally/Downloads/neo4j-5.20.0.tar"
# Out:
# Processing /Users/mariamcnally/Downloads/neo4j-5.20.0.tar
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pytz in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from neo4j==5.20.0) (2023.4)
# Building wheels for collected packages: neo4j
#   Building wheel for neo4j (pyproject.toml) ... done
#   Created wheel for neo4j: filename=neo4j-5.20.0-py3-none-any.whl size=280771 sha256=b073454411711900d7dd2d7a2708dc9ced35524139cc0376f47fe7c39b0801a8
#   Stored in directory: /Users/mariamcnally/Library/Caches/pip/wheels/ed/58/7f/0e263b8192fb836a8b290398eab0e9561a9f1bd70c8c719063
# Successfully built neo4j
# Installing collected packages: neo4j
#   Attempting uninstall: neo4j
#     Found existing installation: neo4j 5.20.0
#     Uninstalling neo4j-5.20.0:
#       Successfully uninstalled neo4j-5.20.0
# Successfully installed neo4j-5.20.0

# %%
from neo4j import GraphDatabase, RoutingControl, basic_auth

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Clean

# %%
df1 = pd.read_csv('Materials/2016_-_Cities_Emissions_Reduction_Targets_20240207.csv')
df2 = pd.read_csv('Materials/2016_-_Citywide_GHG_Emissions_20240207.csv')
df3 = pd.read_csv('Materials/2017_-_Cities_Community_Wide_Emissions.csv')
df4 = pd.read_csv('Materials/2017_-_Cities_Emissions_Reduction_Targets_20240207.csv')
df5 = pd.read_csv('Materials/2023_Cities_Climate_Risk_and_Vulnerability_Assessments_20240207.csv')

dataframes = [df1, df2, df3, df4, df5]

# %%
ac = 'Organisation Number'
ci = 'City'
org = 'Organisation'
co = 'Country'
c40 = 'C40 City'
em = 'Total emissions (metric tonnes CO2e)'
pop = 'City Population'
year = 'Reporting Year'

for df in dataframes:
    df.rename(columns={'Account No': ac, 'Organization Number': ac, 'Account number': ac,
                       'Organization Name': org, 'Organization': org,
                       'Country/Area': co,
                       'City Short Name': ci,
                       'Baseline emissions (metric tonnes CO2e)': em, 'Total City-wide Emissions (metric tonnes CO2e)': em,
                       'Population': pop, 'Current Population': pop,
                       'Reporting year': year,
                       'C40': c40}, inplace=True)

# %%
c40_to_bool = lambda x: False if pd.isnull(x) else (True if x == 'C40' else x)
for df in dataframes:
    df['C40 City'] = df['C40 City'].apply(c40_to_bool)

# %% [markdown]
# ## Setup connection

# %%
# DB URI and authentication
URI = "bolt://localhost:7687"
AUTH = ("neo4j","12345678")

# %%
driver = GraphDatabase.driver(URI, auth=AUTH)

# %%
driver.verify_connectivity()

# %% [markdown]
# ## Query templates

# %%
# template write request
def write_query(query, params={}):
    with driver.session(database="neo4j") as session:
        results = session.execute_write(lambda tx: tx.run(query, params).data())
        # response = [record.values()[0] for record in results]
        return results

# %%
# template read request
def read_query(query, params={}):
    with driver.session(database="neo4j") as session:
        results = session.execute_read(lambda tx: tx.run(query, params).data())       
        response = [record.values()[0] for record in results]
        return response

# %%
for df in dataframes: 
    print(df.isnull().sum())
# Out:
# Organisation                              0
# Organisation Number                       0
# Country                                   0
# City                                      0
# C40 City                                  0
# Reporting Year                            0
# Sector                                   12
# Target boundary                          58
# Baseline year                             5
# Total emissions (metric tonnes CO2e)     18
# Percentage reduction target               0
# Target date                              10
# Comment                                 142
# City Location                             0
# Country Location                          0
# dtype: int64
# Account Number                                   0
# City Name                                        0
# Country                                          0
# City                                             0
# C40 City                                         0
# Reporting Year                                   0
# Measurement Year                                 0
# Boundary                                         0
# Primary Methodology                              0
# Methodology Details                             54
# Gases included                                   6
# Total emissions (metric tonnes CO2e)             0
# Total Scope 1 Emissions (metric tonnes CO2e)    53
# Total Scope 2 Emissions (metric tonnes CO2e)    55
# Increase/Decrease from last year                21
# Reason for increase/decrease in emissions       43
# Current Population Year                          0
# City Population                                  2
# City GDP                                        57
# GDP Currency                                    64
# Year of GDP                                     50
# GDP Source                                      57
# Average annual temperature (in Celsius)​        10
# ​Land area (in square km)                        3
# Average altitude (m)                            19
# City Location                                    0
# Country Location                                 0
# dtype: int64
# Organisation Number                               0
# Organisation                                      0
# City                                              0
# Country                                           0
# Region                                            0
# C40 City                                          0
# Access                                            0
# Reporting Year                                    0
# Accounting year                                   0
# Boundary                                          0
# Protocol                                          0
# Protocol column                                  78
# Gases included                                  118
# Total emissions (metric tonnes CO2e)             12
# Scopes Included                                   0
# Total Scope 1 Emissions (metric tonnes CO2e)     56
# Total Scope 2 Emissions (metric tonnes CO2e)     57
# Comment                                         150
# Increase/Decrease from last year                 20
# Reason for increase/decrease in emissions        51
# City Population                                   0
# Population year                                   0
# GDP                                              48
# GDP Currency                                     45
# GDP Year                                         44
# GDP Source                                       51
# Average annual temperature (in Celsius)​          6
# ​Average altitude (m)                            22
# ​Land area (in square km)                         1
# City Location                                     0
# Country Location                                  0
# dtype: int64
# Organisation Number                                                                     0
# Organisation                                                                            0
# City                                                                                    2
# Country                                                                                 2
# Region                                                                                  2
# Access                                                                                  0
# C40 City                                                                                0
# Reporting Year                                                                          0
# Type of target                                                                          0
# Sector                                                                                108
# Baseline year                                                                          34
# Total emissions (metric tonnes CO2e)                                                  132
# Percentage reduction target                                                            74
# Target date                                                                            56
# Estimated business as usual absolute emissions in target year (metric tonnes CO2e)    375
# ​Intensity unit (emissions per)                                                       383
# Comment                                                                               266
# City Population                                                                         2
# Population Year                                                                         2
# City Location                                                                           2
# Country Location                                                                        2
# dtype: int64
# Questionnaire                                                         0
# Organisation Number                                                   0
# Organisation                                                          0
# City                                                                439
# Country                                                               0
# CDP Region                                                            0
# C40 City                                                              0
# GCoM City                                                             0
# Access                                                                0
# Assessment attachment and/or direct link                             37
# Confirm attachment/link provided                                      0
# Boundary of assessment relative to jurisdiction boundary             12
# Year of publication or approval                                      26
# Factors considered in assessment                                     51
# Primary author(s) of assessment                                      50
# Does the city have adaptation goal(s) and/or an adaptation plan?      0
# City Population                                                       0
# Population Year                                                       8
# City Location                                                       570
# Last update                                                           0
# dtype: int64

# %%
for df in dataframes:
    df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Organisation                          280 non-null    object
#  1   Organisation Number                   280 non-null    int64
#  2   Country                               280 non-null    object
#  3   City                                  280 non-null    object
#  4   C40 City                              280 non-null    bool
#  5   Reporting Year                        280 non-null    int64
#  6   Sector                                268 non-null    object
#  7   Target boundary                       222 non-null    object
#  8   Baseline year                         275 non-null    object
#  9   Total emissions (metric tonnes CO2e)  262 non-null    float64
#  10  Percentage reduction target           280 non-null    float64
#  11  Target date                           270 non-null    float64
#  12  Comment                               138 non-null    object
#  13  City Location                         280 non-null    object
#  14  Country Location                      280 non-null    object
# dtypes: bool(1), float64(3), int64(2), object(9)
# memory usage: 31.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 27 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Account Number                                187 non-null    int64
#  1   City Name                                     187 non-null    object
#  2   Country                                       187 non-null    object
#  3   City                                          187 non-null    object
#  4   C40 City                                      187 non-null    bool
#  5   Reporting Year                                187 non-null    int64
#  6   Measurement Year                              187 non-null    object
#  7   Boundary                                      187 non-null    object
#  8   Primary Methodology                           187 non-null    object
#  9   Methodology Details                           133 non-null    object
#  10  Gases included                                181 non-null    object
#  11  Total emissions (metric tonnes CO2e)          187 non-null    float64
#  12  Total Scope 1 Emissions (metric tonnes CO2e)  134 non-null    float64
#  13  Total Scope 2 Emissions (metric tonnes CO2e)  132 non-null    float64
#  14  Increase/Decrease from last year              166 non-null    object
#  15  Reason for increase/decrease in emissions     144 non-null    object
#  16  Current Population Year                       187 non-null    int64
#  17  City Population                               185 non-null    float64
#  18  City GDP                                      130 non-null    float64
#  19  GDP Currency                                  123 non-null    object
#  20  Year of GDP                                   137 non-null    float64
#  21  GDP Source                                    130 non-null    object
#  22  Average annual temperature (in Celsius)​      177 non-null    float64
#  23  ​Land area (in square km)                     184 non-null    float64
#  24  Average altitude (m)                          168 non-null    float64
#  25  City Location                                 187 non-null    object
#  26  Country Location                              187 non-null    object
# dtypes: bool(1), float64(9), int64(3), object(14)
# memory usage: 38.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 31 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Organisation Number                           229 non-null    int64
#  1   Organisation                                  229 non-null    object
#  2   City                                          229 non-null    object
#  3   Country                                       229 non-null    object
#  4   Region                                        229 non-null    object
#  5   C40 City                                      229 non-null    bool
#  6   Access                                        229 non-null    object
#  7   Reporting Year                                229 non-null    int64
#  8   Accounting year                               229 non-null    object
#  9   Boundary                                      229 non-null    object
#  10  Protocol                                      229 non-null    object
#  11  Protocol column                               151 non-null    object
#  12  Gases included                                111 non-null    object
#  13  Total emissions (metric tonnes CO2e)          217 non-null    float64
#  14  Scopes Included                               229 non-null    object
#  15  Total Scope 1 Emissions (metric tonnes CO2e)  173 non-null    float64
#  16  Total Scope 2 Emissions (metric tonnes CO2e)  172 non-null    float64
#  17  Comment                                       79 non-null     object
#  18  Increase/Decrease from last year              209 non-null    object
#  19  Reason for increase/decrease in emissions     178 non-null    object
#  20  City Population                               229 non-null    int64
#  21  Population year                               229 non-null    int64
#  22  GDP                                           181 non-null    float64
#  23  GDP Currency                                  184 non-null    object
#  24  GDP Year                                      185 non-null    float64
#  25  GDP Source                                    178 non-null    object
#  26  Average annual temperature (in Celsius)​      223 non-null    float64
#  27  ​Average altitude (m)                         207 non-null    float64
#  28  ​Land area (in square km)                     228 non-null    float64
#  29  City Location                                 229 non-null    object
#  30  Country Location                              229 non-null    object
# dtypes: bool(1), float64(8), int64(4), object(18)
# memory usage: 54.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 21 columns):
#  #   Column                                                                              Non-Null Count  Dtype
# ---  ------                                                                              --------------  -----
#  0   Organisation Number                                                                 406 non-null    int64
#  1   Organisation                                                                        406 non-null    object
#  2   City                                                                                404 non-null    object
#  3   Country                                                                             404 non-null    object
#  4   Region                                                                              404 non-null    object
#  5   Access                                                                              406 non-null    object
#  6   C40 City                                                                            406 non-null    bool
#  7   Reporting Year                                                                      406 non-null    int64
#  8   Type of target                                                                      406 non-null    object
#  9   Sector                                                                              298 non-null    object
#  10  Baseline year                                                                       372 non-null    object
#  11  Total emissions (metric tonnes CO2e)                                                274 non-null    float64
#  12  Percentage reduction target                                                         332 non-null    float64
#  13  Target date                                                                         350 non-null    object
#  14  Estimated business as usual absolute emissions in target year (metric tonnes CO2e)  31 non-null     float64
#  15  ​Intensity unit (emissions per)                                                     23 non-null     object
#  16  Comment                                                                             140 non-null    object
#  17  City Population                                                                     404 non-null    float64
#  18  Population Year                                                                     404 non-null    float64
#  19  City Location                                                                       404 non-null    object
#  20  Country Location                                                                    404 non-null    object
# dtypes: bool(1), float64(5), int64(2), object(13)
# memory usage: 64.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 20 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Questionnaire                                                     1370 non-null   object
#  1   Organisation Number                                               1370 non-null   int64
#  2   Organisation                                                      1370 non-null   object
#  3   City                                                              931 non-null    object
#  4   Country                                                           1370 non-null   object
#  5   CDP Region                                                        1370 non-null   object
#  6   C40 City                                                          1370 non-null   bool
#  7   GCoM City                                                         1370 non-null   bool
#  8   Access                                                            1370 non-null   object
#  9   Assessment attachment and/or direct link                          1333 non-null   object
#  10  Confirm attachment/link provided                                  1370 non-null   object
#  11  Boundary of assessment relative to jurisdiction boundary          1358 non-null   object
#  12  Year of publication or approval                                   1344 non-null   float64
#  13  Factors considered in assessment                                  1319 non-null   object
#  14  Primary author(s) of assessment                                   1320 non-null   object
#  15  Does the city have adaptation goal(s) and/or an adaptation plan?  1370 non-null   object
#  16  City Population                                                   1370 non-null   int64
#  17  Population Year                                                   1362 non-null   float64
#  18  City Location                                                     800 non-null    object
#  19  Last update                                                       1370 non-null   object
# dtypes: bool(2), float64(2), int64(2), object(14)
# memory usage: 195.5+ KB

# %%
clean_dfs = []

for df in dataframes:
    clean_dfs.append(df.replace({np.nan: None}))

# %% [markdown]
# ## Input data in database

# %%
dfs = []

for df in clean_dfs:
    dfs.append(df[df['City'].notnull()])

# %%
for df in dfs: 
    print(df.isnull().sum())
# Out:
# Organisation                              0
# Organisation Number                       0
# Country                                   0
# City                                      0
# C40 City                                  0
# Reporting Year                            0
# Sector                                   12
# Target boundary                          58
# Baseline year                             5
# Total emissions (metric tonnes CO2e)     18
# Percentage reduction target               0
# Target date                              10
# Comment                                 142
# City Location                             0
# Country Location                          0
# dtype: int64
# Account Number                                   0
# City Name                                        0
# Country                                          0
# City                                             0
# C40 City                                         0
# Reporting Year                                   0
# Measurement Year                                 0
# Boundary                                         0
# Primary Methodology                              0
# Methodology Details                             54
# Gases included                                   6
# Total emissions (metric tonnes CO2e)             0
# Total Scope 1 Emissions (metric tonnes CO2e)    53
# Total Scope 2 Emissions (metric tonnes CO2e)    55
# Increase/Decrease from last year                21
# Reason for increase/decrease in emissions       43
# Current Population Year                          0
# City Population                                  2
# City GDP                                        57
# GDP Currency                                    64
# Year of GDP                                     50
# GDP Source                                      57
# Average annual temperature (in Celsius)​        10
# ​Land area (in square km)                        3
# Average altitude (m)                            19
# City Location                                    0
# Country Location                                 0
# dtype: int64
# Organisation Number                               0
# Organisation                                      0
# City                                              0
# Country                                           0
# Region                                            0
# C40 City                                          0
# Access                                            0
# Reporting Year                                    0
# Accounting year                                   0
# Boundary                                          0
# Protocol                                          0
# Protocol column                                  78
# Gases included                                  118
# Total emissions (metric tonnes CO2e)             12
# Scopes Included                                   0
# Total Scope 1 Emissions (metric tonnes CO2e)     56
# Total Scope 2 Emissions (metric tonnes CO2e)     57
# Comment                                         150
# Increase/Decrease from last year                 20
# Reason for increase/decrease in emissions        51
# City Population                                   0
# Population year                                   0
# GDP                                              48
# GDP Currency                                     45
# GDP Year                                         44
# GDP Source                                       51
# Average annual temperature (in Celsius)​          6
# ​Average altitude (m)                            22
# ​Land area (in square km)                         1
# City Location                                     0
# Country Location                                  0
# dtype: int64
# Organisation Number                                                                     0
# Organisation                                                                            0
# City                                                                                    0
# Country                                                                                 0
# Region                                                                                  0
# Access                                                                                  0
# C40 City                                                                                0
# Reporting Year                                                                          0
# Type of target                                                                          0
# Sector                                                                                106
# Baseline year                                                                          33
# Total emissions (metric tonnes CO2e)                                                  130
# Percentage reduction target                                                            73
# Target date                                                                            55
# Estimated business as usual absolute emissions in target year (metric tonnes CO2e)    373
# ​Intensity unit (emissions per)                                                       381
# Comment                                                                               265
# City Population                                                                         0
# Population Year                                                                         0
# City Location                                                                           0
# Country Location                                                                        0
# dtype: int64
# Questionnaire                                                         0
# Organisation Number                                                   0
# Organisation                                                          0
# City                                                                  0
# Country                                                               0
# CDP Region                                                            0
# C40 City                                                              0
# GCoM City                                                             0
# Access                                                                0
# Assessment attachment and/or direct link                             18
# Confirm attachment/link provided                                      0
# Boundary of assessment relative to jurisdiction boundary              5
# Year of publication or approval                                      10
# Factors considered in assessment                                     19
# Primary author(s) of assessment                                      21
# Does the city have adaptation goal(s) and/or an adaptation plan?      0
# City Population                                                       0
# Population Year                                                       3
# City Location                                                       159
# Last update                                                           0
# dtype: int64

# %%
create_db = """
MERGE (c:City {name:$city})
SET c.population = CASE trim(toString($city_population)) WHEN 'None' THEN null ELSE $city_population END,
    c.city_gdp = CASE trim(toString($city_gdp)) WHEN 'None' THEN null ELSE $city_gdp END,
    
""" 
#SET c.aliases = CASE trim(toString(c.aliases)) WHEN 'None' THEN null ELSE $aliases END

# %%
for df in dfs:
    for index, row in df.iterrows():
        params = {'city': row['City']}  # Initialize params with mandatory 'city' key
        
        # Check for optional columns and add to params if present
        optional_columns = ['City Population', 'City GDP']
        for column in optional_columns:
            if column in df.columns:
                params[column.lower().replace(' ', '_')] = row[column]
            else:
                params[column.lower().replace(' ', '_')] = None
        
        # Write the query and execute
        response = write_query(create_db, params=params)

# %% [markdown]
# ### Checking in the DB

# %% [markdown]
# ![image.png](attachment:e7a6414e-20c1-47d3-a77d-b4be0cf99f8a.png)

# %%
# Define the Cypher query to add a country relationship to a city
add_country = '''
    MERGE (country:Country {name: $country})
    WITH country
    MATCH (city:City {name: $city})
    MERGE (city)-[:IN_COUNTRY]->(country)
    RETURN city
'''

# %%
# Execute transaction
for df in dfs:
    # Assuming 'Country' and 'City' columns exist in your DataFrame
    for index, row in df.iterrows():
        params = {'country': row['Country'], 'city': row['City']}  # Initialize params with mandatory 'country' and 'city' keys
        
        # Write the query and execute
        response = write_query(add_country, params=params)

# %% [markdown]
# ![image.png](attachment:10c7bed6-34a7-4e0c-af7e-bc5c2d610d27.png)
